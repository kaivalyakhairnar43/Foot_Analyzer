# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set up Chrome options
chrome_options = Options()
# chrome_options.add_argument("--headless")  # Run Chrome in headless mode

# Set path to chromedriver as per your configuration
webdriver_service = Service('C:\\Users\\DELL\\OneDrive\\Desktop\\chromedriver')

# Choose your preferred browser
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Load the webpage
url = 'https://fbref.com/en/comps/12/keepers/La-Liga-Stats#all_stats_keeper'
driver.get(url)

# Get the HTML content of the page
html = driver.page_source

# Use pandas.read_html() to parse the table
dfs = pd.read_html(html, attrs={'id': 'stats_keeper'})

# Check if any tables were extracted
if len(dfs) > 0:
    # Select the first table
    keeping_table = dfs[0]
    
    # Print the DataFrame
    print(keeping_table)
else:
    print("No table found.")
# Out:
#    Unnamed: 0_level_0     Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                 Player             Nation
# 0                   1          Álvaro Aceves             es ESP
# 1                   2     Julen Agirrezabala             es ESP
# 2                   3          Sergio Asenjo             es ESP
# 3                   4            Édgar Badía             es ESP
# 4                   5         Yassine Bounou             ma MAR
# 5                   6          Claudio Bravo             cl CHI
# 6                   7            Juan Carlos             es ESP
# 7                   8       Thibaut Courtois             be BEL
# 8                   9     Stole Dimitrievski             mk MKD
# 9                  10        Marko Dmitrović             rs SRB
# 10                 11        Aitor Fernández             es ESP
# 11                 12       Álvaro Fernández             es ESP
# 12                 13               Fernando             es ESP
# ...

# %%
# Close the browser
driver.quit()

# %%
keeping_table.to_excel('laliga_keeping_stats.xlsx')

# %%
PREMIER LEAGUE


22/23
https://fbref.com/en/comps/9/keepers/Premier-League-Stats#all_stats_keeper
https://fbref.com/en/comps/9/shooting/Premier-League-Stats#all_stats_shooting
https://fbref.com/en/comps/9/passing/Premier-League-Stats#all_stats_passing
https://fbref.com/en/comps/9/defense/Premier-League-Stats#all_stats_defense


21/22
https://fbref.com/en/comps/9/2021-2022/keepers/2021-2022-Premier-League-Stats#all_stats_keeper
https://fbref.com/en/comps/9/2021-2022/shooting/2021-2022-Premier-League-Stats#all_stats_shooting
https://fbref.com/en/comps/9/2021-2022/passing/2021-2022-Premier-League-Stats#all_stats_passing
https://fbref.com/en/comps/9/2021-2022/defense/2021-2022-Premier-League-Stats#all_stats_defense


20/21
https://fbref.com/en/comps/9/2020-2021/keepers/2020-2021-Premier-League-Stats#all_stats_keeper
https://fbref.com/en/comps/9/2020-2021/shooting/2020-2021-Premier-League-Stats#all_stats_shooting
https://fbref.com/en/comps/9/2020-2021/passing/2020-2021-Premier-League-Stats#all_stats_passing
https://fbref.com/en/comps/9/2020-2021/defense/2020-2021-Premier-League-Stats#all_stats_defense


19/20
https://fbref.com/en/comps/9/2019-2020/keepers/2019-2020-Premier-League-Stats#all_stats_keeper
https://fbref.com/en/comps/9/2019-2020/shooting/2019-2020-Premier-League-Stats#all_stats_shooting
https://fbref.com/en/comps/9/2019-2020/passing/2019-2020-Premier-League-Stats#all_stats_passing
https://fbref.com/en/comps/9/2019-2020/defense/2019-2020-Premier-League-Stats#all_stats_defense


18/19
https://fbref.com/en/comps/9/2018-2019/keepers/2018-2019-Premier-League-Stats#all_stats_keeper
https://fbref.com/en/comps/9/2018-2019/shooting/2018-2019-Premier-League-Stats#all_stats_shooting
    'https://fbref.com/en/comps/9/passing/Premier-League-Stats#all_stats_passing': {'id': 'stats_passing'},
    'https://fbref.com/en/comps/9/defense/Premier-League-Stats#all_stats_defense': {'id': 'stats_defense'}
}

# Create an Excel writer object
excel_file = '22PLscraped_data.xlsx'
excel_writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

def extract_table_data(soup, table_id, headers):
    table = soup.find('table', {'id': table_id})
    table_data = []
    if table:
        # Extract table rows
        rows = table.find_all('tr')
        
        # Extract table data from each row
        for row in rows:
            row_data = []
            cells = row.find_all(['th', 'td'])
            
            for cell in cells:
                row_data.append(cell.text.strip())
                
            table_data.append(row_data)
    
    # Create a DataFrame with the extracted table data and headers
    df = pd.DataFrame(table_data, columns=headers)
    return df


# Iterate over the URLs and corresponding table attributes
for i, (url, table_attributes) in enumerate(url_table_mapping.items()):
    # Extract the table ID from the URL
    table_id = url.split('/')[-1].split('#')[0]

    # Load the webpage
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract the table data
    headers = table_attributes
    table = extract_table_data(soup, table_id, headers)

    # Save the DataFrame to a sheet in the Excel file
    sheet_name = f'Sheet{i+1}'
    table.to_excel(excel_writer, sheet_name=sheet_name, index=False)

    print(f'DataFrame for URL {url} saved to sheet {sheet_name}')

    # Add a sleep time of 1 second
    time.sleep(1)

# Save and close the Excel file
excel_writer.save()
excel_writer.close()


# Close the browser
driver.quit()
# Out:
# DataFrame for URL https://fbref.com/en/comps/9/keepers/Premier-League-Stats#all_stats_keeper saved to sheet Sheet1
# DataFrame for URL https://fbref.com/en/comps/9/shooting/Premier-League-Stats#all_stats_shooting saved to sheet Sheet2
# DataFrame for URL https://fbref.com/en/comps/9/passing/Premier-League-Stats#all_stats_passing saved to sheet Sheet3
# DataFrame for URL https://fbref.com/en/comps/9/defense/Premier-League-Stats#all_stats_defense saved to sheet Sheet4
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18348\2307838943.py:76: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   excel_writer.save()
# C:\Users\DELL\anaconda3\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
# Close the browser
driver.quit()

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode

# Set path to chromedriver as per your configuration
webdriver_service = Service('/path/to/chromedriver')

# Choose your preferred browser
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Define the list of URLs and corresponding table attributes to scrape
url_table_mapping = {
    'https://fbref.com/en/comps/9/keepers/Premier-League-Stats#all_stats_keeper': {'id': 'stats_keeper'},
    'https://fbref.com/en/comps/9/shooting/Premier-League-Stats#all_stats_shooting': {'id': 'stats_shooting'},
    'https://fbref.com/en/comps/9/passing/Premier-League-Stats#all_stats_passing': {'id': 'stats_passing'},
    'https://fbref.com/en/comps/9/defense/Premier-League-Stats#all_stats_defense': {'id': 'stats_defense'}
}

# Create an Excel writer object
excel_file = 'scraped_data.xlsx'
excel_writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

# Iterate over the URLs and corresponding table attributes
for i, (url, table_attributes) in enumerate(url_table_mapping.items()):
    # Load the webpage
    driver.get(url)

    # Get the HTML content of the page
    html = driver.page_source

    # Use pandas.read_html() to parse the table
    dfs = pd.read_html(html, attrs=table_attributes)

    # Check if any tables were extracted
    if len(dfs) > 0:
        # Select the first table
        table = dfs[0]

        # Save the DataFrame to a sheet in the Excel file
        sheet_name = f'Sheet{i+1}'
        table.to_excel(excel_writer, sheet_name=sheet_name)

        print(f'DataFrame for URL {url} saved to sheet {sheet_name}')

    # Add a sleep time of 1 second
    time.sleep(1)

# Save the Excel file
excel_writer.save()

# Close the browser
driver.quit()
# Out:
# DataFrame for URL https://fbref.com/en/comps/9/keepers/Premier-League-Stats#all_stats_keeper saved to sheet Sheet1
# DataFrame for URL https://fbref.com/en/comps/9/shooting/Premier-League-Stats#all_stats_shooting saved to sheet Sheet2
# DataFrame for URL https://fbref.com/en/comps/9/passing/Premier-League-Stats#all_stats_passing saved to sheet Sheet3
# DataFrame for URL https://fbref.com/en/comps/9/defense/Premier-League-Stats#all_stats_defense saved to sheet Sheet4
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18348\3829296076.py:55: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   excel_writer.save()

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options


# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode

# Set path to chromedriver as per your configuration
webdriver_service = Service('/path/to/chromedriver')

# Choose your preferred browser
driver = webdriver.Chrome(service=webdriver_service, options=chrome_options)

# Define the list of URLs and corresponding table attributes to scrape
url_table_mapping = {
    'https://fbref.com/en/comps/82/2021-2022/keepers/2021-2022-Indian-Super-League-Stats#all_stats_keeper': {'id': 'stats_keeper'},
    'https://fbref.com/en/comps/82/2021-2022/shooting/2021-2022-Indian-Super-League-Stats#all_stats_shooting': {'id': 'stats_shooting'},
    'https://fbref.com/en/comps/82/2021-2022/passing/2021-2022-Indian-Super-League-Stats#all_stats_passing': {'id': 'stats_passing'},
    'https://fbref.com/en/comps/82/2021-2022/defense/2021-2022-Indian-Super-League-Stats#all_stats_defense': {'id': 'stats_defense'}
}

# Create an Excel writer object
excel_file = 'ISL21scraped_data.xlsx'
excel_writer = pd.ExcelWriter(excel_file, engine='xlsxwriter')

# Iterate over the URLs and corresponding table attributes
for i, (url, table_attributes) in enumerate(url_table_mapping.items()):
    # Load the webpage
    driver.get(url)

    # Get the HTML content of the page
    html = driver.page_source

    # Use pandas.read_html() to parse the table
    dfs = pd.read_html(html, attrs=table_attributes)

    # Check if any tables were extracted
    if len(dfs) > 0:
        # Select the first table
        table = dfs[0]

        # Save the DataFrame to a sheet in the Excel file
        sheet_name = f'Sheet{i+1}'
        table.to_excel(excel_writer, sheet_name=sheet_name)

        print(f'DataFrame for URL {url} saved to sheet {sheet_name}')

    # Add a sleep time of 1 second
    time.sleep(1)

# Save the Excel file
excel_writer.save()

# Close the browser
driver.quit()
# Out:
# DataFrame for URL https://fbref.com/en/comps/82/2021-2022/keepers/2021-2022-Indian-Super-League-Stats#all_stats_keeper saved to sheet Sheet1
# DataFrame for URL https://fbref.com/en/comps/82/2021-2022/shooting/2021-2022-Indian-Super-League-Stats#all_stats_shooting saved to sheet Sheet2
# DataFrame for URL https://fbref.com/en/comps/82/2021-2022/passing/2021-2022-Indian-Super-League-Stats#all_stats_passing saved to sheet Sheet3
# DataFrame for URL https://fbref.com/en/comps/82/2021-2022/defense/2021-2022-Indian-Super-League-Stats#all_stats_defense saved to sheet Sheet4
# C:\Users\DELL\AppData\Local\Temp\ipykernel_8520\3798045010.py:56: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   excel_writer.save()
